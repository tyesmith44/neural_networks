# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df.drop(columns=['EIN'], inplace=True)

# %%
# confirm columns dropped
application_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34299 entries, 0 to 34298
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   NAME                    34299 non-null  object
#  1   APPLICATION_TYPE        34299 non-null  object
#  2   AFFILIATION             34299 non-null  object
#  3   CLASSIFICATION          34299 non-null  object
#  4   USE_CASE                34299 non-null  object
#  5   ORGANIZATION            34299 non-null  object
#  6   STATUS                  34299 non-null  int64
#  7   INCOME_AMT              34299 non-null  object
#  8   SPECIAL_CONSIDERATIONS  34299 non-null  object
#  9   ASK_AMT                 34299 non-null  int64
#  10  IS_SUCCESSFUL           34299 non-null  int64
# dtypes: int64(3), object(8)
# memory usage: 2.9+ MB

# %%
app_object = application_df.dtypes[application_df.dtypes != 'object'].index.tolist()
app_object
# Out:
# ['STATUS', 'ASK_AMT', 'IS_SUCCESSFUL']

# %%
# Determine the number of unique values in each column.
application_df[app_object].nunique()
# Out:
# STATUS              2
# ASK_AMT          8747
# IS_SUCCESSFUL       2
# dtype: int64

# %%
# further preproccessing
app_cat = application_df.dtypes[application_df.dtypes == 'object'].index.tolist()
application_df[app_cat].nunique()
# Out:
# NAME                      19568
# APPLICATION_TYPE             17
# AFFILIATION                   6
# CLASSIFICATION               71
# USE_CASE                      5
# ORGANIZATION                  4
# INCOME_AMT                    9
# SPECIAL_CONSIDERATIONS        2
# dtype: int64

# %%
# binning names
name_count = application_df['NAME'].value_counts()
name_count
# Out:
# NAME
# PARENT BOOSTER USA INC                                                  1260
# TOPS CLUB INC                                                            765
# UNITED STATES BOWLING CONGRESS INC                                       700
# WASHINGTON STATE UNIVERSITY                                              492
# AMATEUR ATHLETIC UNION OF THE UNITED STATES INC                          408
#                                                                         ...
# ST LOUIS SLAM WOMENS FOOTBALL                                              1
# AIESEC ALUMNI IBEROAMERICA CORP                                            1
# WEALLBLEEDRED ORG INC                                                      1
# AMERICAN SOCIETY FOR STANDARDS IN MEDIUMSHIP & PSYCHICAL INVESTIGATI       1
# WATERHOUSE CHARITABLE TR                                                   1
# Name: count, Length: 19568, dtype: int64

# %%
# binning names cont'd
replace_name = list(name_count[name_count < 175].index)

for name_count in replace_name:
  application_df['NAME'] = application_df['NAME'].replace(name_count, "Other")

application_df['NAME'].value_counts()
# Out:
# NAME
# Other                                                                 27926
# PARENT BOOSTER USA INC                                                 1260
# TOPS CLUB INC                                                           765
# UNITED STATES BOWLING CONGRESS INC                                      700
# WASHINGTON STATE UNIVERSITY                                             492
# AMATEUR ATHLETIC UNION OF THE UNITED STATES INC                         408
# PTA TEXAS CONGRESS                                                      368
# SOROPTIMIST INTERNATIONAL OF THE AMERICAS INC                           331
# ALPHA PHI SIGMA                                                         313
# TOASTMASTERS INTERNATIONAL                                              293
# MOST WORSHIPFUL STRINGER FREE AND ACCEPTED MASONS                       287
# LITTLE LEAGUE BASEBALL INC                                              277
# INTERNATIONAL ASSOCIATION OF LIONS CLUBS                                266
# MOMS CLUB                                                               210
# INTERNATIONAL ASSOCIATION OF SHEET METAL AIR RAIL & TRANSPORTATION      206
# AMERICAN ASSOCIATION OF UNIVERSITY WOMEN                                197
# Name: count, dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
app_count = application_df['APPLICATION_TYPE'].value_counts()
print(app_count)
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# Choose a cutoff value (250) and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = list(app_count[app_count < 250].index)
application_types_to_replace

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
class_count = application_df['CLASSIFICATION'].value_counts()
class_count
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
class_count[class_count > 1]
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(class_count[class_count < 150].index)
classifications_to_replace

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# Other     1003
# C7000      777
# C1700      287
# C4000      194
# Name: count, dtype: int64

# %%
app_cat = application_df.dtypes[application_df.dtypes == 'object'].index.tolist()
application_df[app_cat].nunique()
# Out:
# NAME                      16
# APPLICATION_TYPE           9
# AFFILIATION                6
# CLASSIFICATION             9
# USE_CASE                   5
# ORGANIZATION               4
# INCOME_AMT                 9
# SPECIAL_CONSIDERATIONS     2
# dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_df = pd.get_dummies(application_df)
application_df.head()
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  NAME_ALPHA PHI SIGMA  \
# 0       1     5000              1                 False
# 1       1   108590              1                 False
# 2       1     5000              0                 False
# 3       1     6692              1                 False
# 4       1   142590              1                 False
#
#    NAME_AMATEUR ATHLETIC UNION OF THE UNITED STATES INC  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    NAME_AMERICAN ASSOCIATION OF UNIVERSITY WOMEN  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#    NAME_INTERNATIONAL ASSOCIATION OF LIONS CLUBS  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#    NAME_INTERNATIONAL ASSOCIATION OF SHEET METAL AIR RAIL & TRANSPORTATION  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    NAME_LITTLE LEAGUE BASEBALL INC  NAME_MOMS CLUB  ...  INCOME_AMT_1-9999  \
# 0                            False           False  ...              False
# 1                            False           False  ...               True
# 2                            False           False  ...              False
# 3                            False           False  ...              False
# 4                            False           False  ...              False
#
#    INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  INCOME_AMT_10M-50M  \
# 0                   False                     False               False
# 1                   False                     False               False
# 2                   False                     False               False
# 3                    True                     False               False
# 4                   False                      True               False
#
#    INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  INCOME_AMT_50M+  \
# 0             False                   False            False
# 1             False                   False            False
# 2             False                   False            False
# 3             False                   False            False
# 4             False                   False            False
#
#    INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  SPECIAL_CONSIDERATIONS_Y
# 0              False                      True                     False
# 1              False                      True                     False
# 2              False                      True                     False
# 3              False                      True                     False
# 4              False                      True                     False
#
# [5 rows x 63 columns]

# %%
# drop odd columns
#application_df = application_df.drop(app_cat, axis=1)

# confirm all data is numerical
application_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34299 entries, 0 to 34298
# Data columns (total 63 columns):
#  #   Column                                                                   Non-Null Count  Dtype
# ---  ------                                                                   --------------  -----
#  0   STATUS                                                                   34299 non-null  int64
#  1   ASK_AMT                                                                  34299 non-null  int64
#  2   IS_SUCCESSFUL                                                            34299 non-null  int64
#  3   NAME_ALPHA PHI SIGMA                                                     34299 non-null  bool
#  4   NAME_AMATEUR ATHLETIC UNION OF THE UNITED STATES INC                     34299 non-null  bool
#  5   NAME_AMERICAN ASSOCIATION OF UNIVERSITY WOMEN                            34299 non-null  bool
#  6   NAME_INTERNATIONAL ASSOCIATION OF LIONS CLUBS                            34299 non-null  bool
#  7   NAME_INTERNATIONAL ASSOCIATION OF SHEET METAL AIR RAIL & TRANSPORTATION  34299 non-null  bool
#  8   NAME_LITTLE LEAGUE BASEBALL INC                                          34299 non-null  bool
#  9   NAME_MOMS CLUB                                                           34299 non-null  bool
#  10  NAME_MOST WORSHIPFUL STRINGER FREE AND ACCEPTED MASONS                   34299 non-null  bool
#  11  NAME_Other                                                               34299 non-null  bool
#  12  NAME_PARENT BOOSTER USA INC                                              34299 non-null  bool
#  13  NAME_PTA TEXAS CONGRESS                                                  34299 non-null  bool
#  14  NAME_SOROPTIMIST INTERNATIONAL OF THE AMERICAS INC                       34299 non-null  bool
#  15  NAME_TOASTMASTERS INTERNATIONAL                                          34299 non-null  bool
#  16  NAME_TOPS CLUB INC                                                       34299 non-null  bool
#  17  NAME_UNITED STATES BOWLING CONGRESS INC                                  34299 non-null  bool
#  18  NAME_WASHINGTON STATE UNIVERSITY                                         34299 non-null  bool
#  19  APPLICATION_TYPE_Other                                                   34299 non-null  bool
#  20  APPLICATION_TYPE_T10                                                     34299 non-null  bool
#  21  APPLICATION_TYPE_T19                                                     34299 non-null  bool
#  22  APPLICATION_TYPE_T3                                                      34299 non-null  bool
#  23  APPLICATION_TYPE_T4                                                      34299 non-null  bool
#  24  APPLICATION_TYPE_T5                                                      34299 non-null  bool
#  25  APPLICATION_TYPE_T6                                                      34299 non-null  bool
#  26  APPLICATION_TYPE_T7                                                      34299 non-null  bool
#  27  APPLICATION_TYPE_T8                                                      34299 non-null  bool
#  28  AFFILIATION_CompanySponsored                                             34299 non-null  bool
#  29  AFFILIATION_Family/Parent                                                34299 non-null  bool
#  30  AFFILIATION_Independent                                                  34299 non-null  bool
#  31  AFFILIATION_National                                                     34299 non-null  bool
#  32  AFFILIATION_Other                                                        34299 non-null  bool
#  33  AFFILIATION_Regional                                                     34299 non-null  bool
#  34  CLASSIFICATION_C1000                                                     34299 non-null  bool
#  35  CLASSIFICATION_C1200                                                     34299 non-null  bool
#  36  CLASSIFICATION_C1700                                                     34299 non-null  bool
#  37  CLASSIFICATION_C2000                                                     34299 non-null  bool
#  38  CLASSIFICATION_C2100                                                     34299 non-null  bool
#  39  CLASSIFICATION_C3000                                                     34299 non-null  bool
#  40  CLASSIFICATION_C4000                                                     34299 non-null  bool
#  41  CLASSIFICATION_C7000                                                     34299 non-null  bool
#  42  CLASSIFICATION_Other                                                     34299 non-null  bool
#  43  USE_CASE_CommunityServ                                                   34299 non-null  bool
#  44  USE_CASE_Heathcare                                                       34299 non-null  bool
#  45  USE_CASE_Other                                                           34299 non-null  bool
#  46  USE_CASE_Preservation                                                    34299 non-null  bool
#  47  USE_CASE_ProductDev                                                      34299 non-null  bool
#  48  ORGANIZATION_Association                                                 34299 non-null  bool
#  49  ORGANIZATION_Co-operative                                                34299 non-null  bool
#  50  ORGANIZATION_Corporation                                                 34299 non-null  bool
#  51  ORGANIZATION_Trust                                                       34299 non-null  bool
#  52  INCOME_AMT_0                                                             34299 non-null  bool
#  53  INCOME_AMT_1-9999                                                        34299 non-null  bool
#  54  INCOME_AMT_10000-24999                                                   34299 non-null  bool
#  55  INCOME_AMT_100000-499999                                                 34299 non-null  bool
#  56  INCOME_AMT_10M-50M                                                       34299 non-null  bool
#  57  INCOME_AMT_1M-5M                                                         34299 non-null  bool
#  58  INCOME_AMT_25000-99999                                                   34299 non-null  bool
#  59  INCOME_AMT_50M+                                                          34299 non-null  bool
#  60  INCOME_AMT_5M-10M                                                        34299 non-null  bool
#  61  SPECIAL_CONSIDERATIONS_N                                                 34299 non-null  bool
#  62  SPECIAL_CONSIDERATIONS_Y                                                 34299 non-null  bool
# dtypes: bool(60), int64(3)
# memory usage: 2.7 MB

# %%
# Split our preprocessed data into our features and target arrays
y= application_df['IS_SUCCESSFUL'].values
X= application_df.drop(['IS_SUCCESSFUL'], axis=1).values

# Split the preprocessed data into a training and testing dataset
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=1)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# **Compile, Train, and Evaluate Model**

# %%
# troubleshooting
len(X_train[0])
# Out:
# 62

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
#hidden_nodes_l1= (number_input_features * 3)
#hidden_nodes_l2= (number_input_features * .6)
hidden_nodes_l1 =  100
hidden_nodes_l2 = 30
hidden_nodes_l3 = 10


nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(
        units=hidden_nodes_l1,
        input_dim=number_input_features,
        activation='relu'
        )
)

# Second hidden layer
nn.add(
    tf.keras.layers.Dense(
        units=hidden_nodes_l2,
        activation='sigmoid'
        )
)

# third hidden layer
nn.add(
    tf.keras.layers.Dense(
        units=hidden_nodes_l3,
        activation='sigmoid'
        )
)

# Output layer
nn.add(
    tf.keras.layers.Dense(
        units=1,
        activation='sigmoid'
    )
)

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)